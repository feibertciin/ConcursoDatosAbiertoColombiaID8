# %% [markdown]
# # 🤖 11. AutoML con PyCaret
#
# Uso de PyCaret para entrenamiento rápido e iterativo de múltiples clasificadores en paralelo.

# %%
print("Configurando entorno de AutoML con PyCaret...")
# Nota: PyCaret se ejecuta sobre dataframes crudos y maneja el pipeline de preprocesamiento automáticamente
import pandas as pd
df = pd.read_csv("data/processed/processed_students.csv")
print(f"Dataset cargado con éxito para AutoML: {df.shape[0]} registros")
