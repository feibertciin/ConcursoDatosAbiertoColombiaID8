# %% [markdown]
# # 🚀 18. Registro de Modelos y Estrategia de Despliegue
#
# Configuración del servidor de base de datos SQLite y tracking MLOps con MLflow.

# %%
print("Estrategia de despliegue en producción:")
print("1. Base de datos: SQLite relacional en local (escalable a PostgreSQL)")
print("2. Tracking: MLflow local con URI configurada en config.yaml")
print("3. Inferencia: Modelos serializados listos en la carpeta /models")
