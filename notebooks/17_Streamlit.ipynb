# %% [markdown]
# # 🖥️ 17. Interfaz de Usuario e Interactividad (Streamlit)
#
# Documentación y guía de desarrollo para la visualización premium y mapas interactivos en Streamlit.

# %%
print("Para ejecutar el dashboard interactivo:")
print("streamlit run app.py")
print("Verificar el puerto 8501 y el tema de color configurado en .streamlit/config.toml.")
