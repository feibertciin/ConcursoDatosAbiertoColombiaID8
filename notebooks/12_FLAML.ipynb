# %% [markdown]
# # ⚡ 12. Optimización Ligera de Modelos con FLAML
#
# AutoML eficiente enfocado en restricciones de tiempo computacional.

# %%
print("Configurando FLAML AutoML...")
import pandas as pd
df = pd.read_csv("data/processed/processed_students.csv")
print(f"FLAML listo para optimizar sobre variable: 'desertor'")
