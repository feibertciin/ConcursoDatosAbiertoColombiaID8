# %% [markdown]
# # 🛡️ 13. Explicabilidad con SHAP
#
# Explicación global y local para comprender la contribución marginal de cada variable predictora.

# %%
import joblib
import pandas as pd

model = joblib.load("models/randomforest_model.pkl")
print(f"Modelo cargado: {model}")
print("El análisis SHAP calcula la contribución de 'promedio_acumulado' e 'ingresos' al riesgo de deserción.")
