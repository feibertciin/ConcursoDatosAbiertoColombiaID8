# %% [markdown]
# # 🛡️ 14. Explicabilidad Local con LIME
#
# Generación de explicaciones interpretables para predicciones de estudiantes específicos (e.g. alertas tempranas).

# %%
print("Inicializando LIME explainer para instancias locales...")
print("LIME aproxima localmente la frontera de decisión para justificar por qué Andrea Carolina tiene alto riesgo.")
